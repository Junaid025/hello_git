# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Housing.csv")
df
# Out:
#        price    area  length  width  bedrooms  bathrooms  stories mainroad  \
# 0    1465896  244316     593    412         4          2        3      yes
# 1    3123904  390488     734    532         4          4        4      yes
# 2    1519896  379974     498    763         3          2        2      yes
# 3    1152112  288028     382    754         4          2        2      yes
# 4     887292  221823     503    441         4          1        2      yes
# ..       ...     ...     ...    ...       ...        ...      ...      ...
# 540   377880  188940     470    402         2          1        1      yes
# 541   483084  241542     497    486         3          1        1       no
# 542   364276  182138     374    487         2          1        1      yes
# 543   734160  367080     570    644         3          1        1       no
# 544  1625268  406317     527    771         3          1        2      yes
#
# ...

# %%
area = df['area'].to_numpy()
Mean = area.mean()
Min = min(area)
Max = max(area)
df['area'].describe()
std = 113027.434541
z_score = (area-Mean)/std

# %% [markdown]
# # Range Normalization

# %%
df['price'].describe()
Min = 2.004660e+05
price = df['price'].to_numpy()
price = price-Min
Max = max(price)
price = price/Max
price
# Out:
# array([2.87068608e-01, 6.63195338e-01, 2.99318756e-01, 2.15885266e-01,
#        1.55809633e-01, 5.84336598e-02, 4.34112125e-01, 3.47704118e-01,
#        4.22052535e-01, 4.26834630e-01, 2.04099716e-01, 1.60412966e-01,
#        1.05967864e-01, 2.43534304e-01, 2.87961507e-01, 2.63299691e-01,
#        3.63369789e-01, 3.46500881e-01, 9.17903591e-02, 1.38896262e-01,
#        8.26798787e-02, 7.48524878e-02, 3.15341496e-02, 4.54786745e-01,
#        2.04935449e-01, 1.92034682e-01, 6.55776285e-01, 1.02580017e-01,
#        1.55123624e-01, 2.91451438e-01, 1.54153594e-01, 3.93274669e-01,
#        2.59100159e-01, 1.73015192e-01, 1.50607403e-01, 2.94387844e-01,
#        4.91200991e-01, 3.98664734e-01, 3.64295356e-01, 4.60862819e-01,
#        1.78839911e-01, 2.24189959e-01, 5.83164667e-01, 3.49460880e-01,
#        6.50059549e-01, 6.44811041e-01, 2.88527736e-01, 3.47335706e-01,
#        2.42341956e-01, 1.24834453e-01, 4.51389371e-01, 3.70774323e-01,
# ...

# %%
df['parking'].describe()
Min = 0
parking = df['parking'].to_numpy()
parking = parking-Min
Max = max(parking)
parking = parking/Max
parking
# Out:
# array([0.66666667, 1.        , 0.66666667, 1.        , 0.66666667,
#        0.66666667, 0.66666667, 0.        , 0.66666667, 0.33333333,
#        0.66666667, 0.66666667, 0.33333333, 0.66666667, 0.        ,
#        0.66666667, 0.33333333, 0.66666667, 0.66666667, 0.33333333,
#        0.66666667, 0.66666667, 0.33333333, 0.33333333, 0.66666667,
#        0.66666667, 0.        , 0.33333333, 0.66666667, 0.33333333,
#        0.66666667, 0.66666667, 0.33333333, 0.33333333, 0.33333333,
#        0.66666667, 0.33333333, 0.66666667, 0.66666667, 0.33333333,
#        0.        , 0.        , 0.66666667, 0.66666667, 0.33333333,
#        0.        , 0.33333333, 1.        , 0.33333333, 0.        ,
#        0.33333333, 0.33333333, 0.33333333, 0.66666667, 0.33333333,
#        0.33333333, 0.33333333, 0.33333333, 0.33333333, 0.33333333,
#        0.33333333, 0.33333333, 0.33333333, 0.66666667, 0.33333333,
#        0.33333333, 0.33333333, 0.66666667, 0.33333333, 0.66666667,
# ...

# %%
df['stories'].describe()
Min = 1
stories = df['stories'].to_numpy()
stories = stories-Min
Max = max(stories)
stories = stories/Max
stories
# Out:
# array([0.66666667, 1.        , 0.33333333, 0.33333333, 0.33333333,
#        0.        , 1.        , 0.33333333, 0.33333333, 1.        ,
#        0.33333333, 0.33333333, 0.33333333, 0.33333333, 0.33333333,
#        0.33333333, 0.33333333, 1.        , 0.33333333, 0.33333333,
#        0.33333333, 0.        , 0.        , 0.33333333, 0.33333333,
#        0.33333333, 1.        , 0.        , 0.33333333, 0.33333333,
#        1.        , 1.        , 0.33333333, 0.33333333, 0.33333333,
#        1.        , 0.66666667, 1.        , 1.        , 1.        ,
#        0.33333333, 1.        , 1.        , 1.        , 1.        ,
#        0.66666667, 1.        , 1.        , 0.33333333, 0.        ,
#        1.        , 1.        , 1.        , 1.        , 0.33333333,
#        0.33333333, 0.33333333, 1.        , 1.        , 1.        ,
#        0.33333333, 0.        , 0.33333333, 0.66666667, 0.        ,
#        0.33333333, 0.        , 0.        , 0.        , 0.33333333,
# ...

# %%
df['bathrooms'].describe()
Min = 1
bathrooms = df['bathrooms'].to_numpy()
bathrooms = bathrooms-Min
Max = max(bathrooms)
bathrooms = bathrooms/Max
bathrooms
# Out:
# array([0.33333333, 1.        , 0.33333333, 0.33333333, 0.        ,
#        0.66666667, 0.66666667, 0.66666667, 0.        , 0.33333333,
#        0.        , 0.66666667, 0.33333333, 0.33333333, 0.33333333,
#        0.        , 0.33333333, 0.33333333, 0.33333333, 0.33333333,
#        0.        , 0.33333333, 0.        , 0.33333333, 0.33333333,
#        0.33333333, 0.33333333, 0.        , 0.33333333, 0.33333333,
#        0.33333333, 0.        , 0.33333333, 0.66666667, 0.        ,
#        0.33333333, 0.33333333, 0.33333333, 0.        , 0.33333333,
#        0.        , 0.33333333, 0.33333333, 0.33333333, 0.33333333,
#        0.33333333, 0.33333333, 0.        , 0.33333333, 0.33333333,
#        0.33333333, 0.        , 0.33333333, 0.33333333, 0.33333333,
#        0.        , 0.        , 0.33333333, 0.33333333, 0.33333333,
#        0.33333333, 0.        , 0.33333333, 0.33333333, 0.        ,
#        0.33333333, 0.        , 0.33333333, 0.        , 0.33333333,
# ...

# %%
df['bedrooms'].describe()
Min = 1
bedrooms = df['bedrooms'].to_numpy()
bedrooms = bedrooms-Min
Max = max(bedrooms)
bedrooms = bedrooms/Max
bedrooms
# Out:
# array([0.6, 0.6, 0.4, 0.6, 0.6, 0.4, 0.6, 0.8, 0.6, 0.4, 0.4, 0.6, 0.6,
#        0.6, 0.4, 0.6, 0.6, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.6,
#        0.4, 0.4, 0.8, 0.6, 0.4, 0.4, 0.6, 0.4, 0.8, 0.4, 0.4, 0.6, 0.4,
#        0.6, 0.4, 0.4, 0.4, 0.6, 0.6, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4,
#        0.6, 0.4, 0.4, 0.4, 0.6, 0.6, 0.6, 0.4, 0.4, 0.2, 0.6, 0.6, 0.4,
#        0.4, 0.2, 0.4, 0.4, 0.6, 0.4, 0.6, 0.4, 0.2, 0.4, 0.6, 0.4, 0.4,
#        0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.8, 0.4,
#        0.2, 0.4, 0.4, 0.6, 0.4, 0.4, 0.4, 0.4, 0.6, 0.4, 0.4, 0.4, 0.4,
#        0.4, 0.4, 0.6, 0.4, 0.6, 0.6, 0.4, 0.4, 1. , 0.4, 0.2, 0.4, 0.4,
#        0.6, 0.4, 0.4, 0.4, 0.4, 0.6, 0.6, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4,
#        0.4, 0.6, 0.4, 0.4, 0.4, 0.4, 0.6, 0.6, 0.4, 0.4, 0.4, 0.6, 0.6,
#        0.8, 0.6, 0.4, 0.2, 0.4, 0.4, 0.6, 0.4, 0.6, 0.8, 0.4, 0.4, 0.4,
#        0.4, 0.6, 0.4, 0.4, 0.6, 0.4, 0.6, 0.4, 0.4, 0.4, 0.4, 0.2, 0.6,
# ...

# %%
df['area'].describe()
Min = 94828.000000
Area = df['area'].to_numpy()
Area = Area-Min
Max = max(Area)
Area = Area/Max
Area
# Out:
# array([0.288093  , 0.56979541, 0.54953285, 0.37233468, 0.24474453,
#        0.25862228, 0.32652904, 0.65229491, 0.81019796, 0.31880097,
#        0.34730424, 0.25452121, 0.13888932, 0.43105641, 0.52541203,
#        0.47303464, 0.68556606, 0.23349355, 0.10877877, 0.20882348,
#        0.0894297 , 0.32836373, 0.14436256, 0.87971971, 0.34907918,
#        0.32168021, 0.56191702, 0.44614059, 0.24328757, 0.53282404,
#        0.02923752, 0.28316323, 0.46411557, 0.28128613, 0.2336959 ,
#        0.17815405, 0.57712069, 0.288887  , 0.25238973, 0.35493594,
#        0.29365682, 0.10361003, 0.48480982, 0.23663681, 0.55584635,
#        0.79461464, 0.17193113, 0.23438006, 0.42852407, 0.54066966,
#        0.34487597, 0.25926982, 0.38905506, 0.18646028, 0.26153428,
#        0.31061809, 0.12382634, 0.44383759, 0.39102465, 0.22134449,
#        0.        , 0.45296866, 0.63593878, 0.45130356, 0.37188179,
#        0.49099613, 0.68785942, 0.36258306, 0.33115817, 0.78732212,
# ...

# %%
df['length'].describe()
Min = 300.000000
length = df['length'].to_numpy()
length = length-Min
Max = max(length)
length = length/Max
length
# Out:
# array([0.586, 0.868, 0.396, 0.164, 0.406, 0.488, 0.124, 0.816, 0.74 ,
#        0.15 , 0.12 , 0.328, 0.132, 0.708, 0.746, 0.34 , 0.808, 0.114,
#        0.192, 0.064, 0.128, 0.234, 0.184, 0.888, 0.946, 0.958, 0.8  ,
#        0.35 , 0.038, 0.372, 0.034, 0.732, 0.748, 0.208, 0.772, 0.01 ,
#        0.826, 0.636, 0.74 , 0.12 , 0.126, 0.18 , 0.434, 0.472, 0.9  ,
#        0.896, 0.126, 0.13 , 0.344, 0.45 , 0.57 , 0.904, 0.616, 0.018,
#        0.246, 0.548, 0.176, 0.62 , 0.258, 0.014, 0.004, 0.282, 0.626,
#        0.806, 0.522, 0.35 , 0.79 , 0.704, 0.148, 0.808, 0.13 , 0.692,
#        0.456, 0.116, 0.05 , 0.224, 0.842, 0.752, 0.32 , 0.298, 0.064,
#        0.402, 0.226, 0.406, 0.5  , 0.192, 0.632, 0.766, 0.278, 0.086,
#        0.51 , 0.262, 0.984, 0.874, 0.756, 0.552, 0.152, 0.52 , 0.266,
#        0.092, 0.27 , 0.398, 0.912, 0.548, 0.418, 0.352, 0.786, 0.154,
#        0.93 , 0.666, 0.638, 0.954, 0.316, 0.758, 0.38 , 0.18 , 0.642,
# ...

# %%
df['width'].describe()
Min = 300.000000
width = df['width'].to_numpy()
width = width-Min
Max = max(width)
width = width/Max
width
# Out:
# array([0.224, 0.464, 0.926, 0.908, 0.282, 0.242, 0.86 , 0.624, 0.938,
#        0.788, 0.928, 0.378, 0.312, 0.374, 0.492, 0.848, 0.68 , 0.61 ,
#        0.164, 0.624, 0.176, 0.672, 0.266, 0.882, 0.114, 0.072, 0.504,
#        0.774, 0.786, 0.928, 0.094, 0.126, 0.396, 0.592, 0.03 , 0.628,
#        0.506, 0.192, 0.074, 0.95 , 0.762, 0.162, 0.74 , 0.212, 0.422,
#        0.756, 0.414, 0.586, 0.744, 0.83 , 0.336, 0.01 , 0.376, 0.64 ,
#        0.49 , 0.292, 0.22 , 0.466, 0.788, 0.766, 0.028, 0.896, 0.786,
#        0.336, 0.426, 0.872, 0.7  , 0.268, 0.826, 0.83 , 0.33 , 0.714,
#        0.364, 0.12 , 0.642, 0.85 , 0.876, 0.508, 0.308, 0.752, 0.436,
#        0.21 , 0.104, 0.36 , 0.666, 0.708, 0.32 , 0.278, 0.066, 0.832,
#        0.484, 0.326, 0.298, 0.064, 0.252, 0.452, 0.6  , 0.468, 0.112,
#        0.776, 0.216, 0.144, 0.924, 0.35 , 0.132, 0.988, 0.336, 0.426,
#        0.768, 0.85 , 0.242, 0.882, 0.41 , 0.092, 0.724, 0.928, 0.828,
# ...

# %%
df['furnishingstatus'].replace("furnished",1 ,inplace = True)
df['furnishingstatus'].replace("unfurnished",0 ,inplace = True)
df['furnishingstatus'].replace("semi-furnished",-1 ,inplace = True)

# %%
df
# Out:
#        price    area  length  width  bedrooms  bathrooms  stories mainroad  \
# 0    1465896  244316     593    412         4          2        3      yes
# 1    3123904  390488     734    532         4          4        4      yes
# 2    1519896  379974     498    763         3          2        2      yes
# 3    1152112  288028     382    754         4          2        2      yes
# 4     887292  221823     503    441         4          1        2      yes
# ..       ...     ...     ...    ...       ...        ...      ...      ...
# 540   377880  188940     470    402         2          1        1      yes
# 541   483084  241542     497    486         3          1        1       no
# 542   364276  182138     374    487         2          1        1      yes
# 543   734160  367080     570    644         3          1        1       no
# 544  1625268  406317     527    771         3          1        2      yes
#
# ...

# %%
y = df["furnishingstatus"]
df = df.drop(['mainroad' ,'guestroom' ,'basement', 'hotwaterheating' ,'airconditioning','prefarea','furnishingstatus'],axis = 1)
df
# Out:
#        price    area  length  width  bedrooms  bathrooms  stories  parking
# 0    1465896  244316     593    412         4          2        3        2
# 1    3123904  390488     734    532         4          4        4        3
# 2    1519896  379974     498    763         3          2        2        2
# 3    1152112  288028     382    754         4          2        2        3
# 4     887292  221823     503    441         4          1        2        2
# ..       ...     ...     ...    ...       ...        ...      ...      ...
# 540   377880  188940     470    402         2          1        1        2
# 541   483084  241542     497    486         3          1        1        0
# 542   364276  182138     374    487         2          1        1        0
# 543   734160  367080     570    644         3          1        1        0
# 544  1625268  406317     527    771         3          1        2        0
#
# [545 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test =train_test_split(df, y, test_size=0.4, random_state=50)

clf1=KNeighborsClassifier()
clf1.fit(X_train, y_train)
pred=clf1.predict(X_test)
 
print ("Accuracy : " , accuracy_score(y_test,pred)*100)  
print("F1 Score : ",f1_score(y_test, pred, average='micro')*100)
# Out:
# Accuracy :  34.403669724770644
# F1 Score :  34.403669724770644

# %%
normalized = pd.DataFrame({"price":price,"area":Area,"length":length ,"width":width ,"bedrooms":bedrooms, "bathrooms":bathrooms, "stories":stories,"parking":parking })
normalized
# Out:
#         price      area  length  width  bedrooms  bathrooms   stories  \
# 0    0.287069  0.288093   0.586  0.224       0.6   0.333333  0.666667
# 1    0.663195  0.569795   0.868  0.464       0.6   1.000000  1.000000
# 2    0.299319  0.549533   0.396  0.926       0.4   0.333333  0.333333
# 3    0.215885  0.372335   0.164  0.908       0.6   0.333333  0.333333
# 4    0.155810  0.244745   0.406  0.282       0.6   0.000000  0.333333
# ..        ...       ...     ...    ...       ...        ...       ...
# 540  0.040247  0.181372   0.340  0.204       0.2   0.000000  0.000000
# 541  0.064113  0.282747   0.394  0.372       0.4   0.000000  0.000000
# 542  0.037161  0.168264   0.148  0.374       0.2   0.000000  0.000000
# 543  0.121071  0.524684   0.540  0.688       0.4   0.000000  0.000000
# 544  0.323223  0.600301   0.454  0.942       0.4   0.000000  0.333333
#
#       parking
# 0    0.666667
# 1    1.000000
# 2    0.666667
# 3    1.000000
# 4    0.666667
# ..        ...
# 540  0.666667
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test =train_test_split(normalized, y, test_size=0.3, random_state=50)

clf1=KNeighborsClassifier()
clf1.fit(X_train, y_train)
pred=clf1.predict(X_test)
 
print ("Accuracy : " , accuracy_score(y_test,pred)*100)  
print("F1 Score : ",f1_score(y_test, pred, average='micro')*100)
# Out:
# Accuracy :  40.853658536585364
# F1 Score :  40.853658536585364

# %% [markdown]
# # Area Plotes

# %%
plot = df.plot.scatter("area","length")
plot
# Out:
# <AxesSubplot:xlabel='area', ylabel='length'>

# %%
plot = normalized.plot.scatter("area","length")
plot
# Out:
# <AxesSubplot:xlabel='area', ylabel='length'>

# %%
plot = df.plot.scatter("area","width")
plot
# Out:
# <AxesSubplot:xlabel='area', ylabel='width'>

# %%
plot = normalized.plot.scatter("area","width")
plot
# Out:
# <AxesSubplot:xlabel='area', ylabel='width'>

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (16, 9))
plotted = plt.axes(projection ="3d")
sctt = plotted.scatter3D(df['area'],  df["width"],df["length"],color='pink',edgecolor='red', s=65)
plt.title(" Houses Area  ")
plotted.set_xlabel('X-axis', fontweight ='bold')
plotted.set_ylabel('Y-axis', fontweight ='bold')
plotted.set_zlabel('Z-axis', fontweight ='bold')
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (16, 9))
plotted = plt.axes(projection ="3d")
sctt = plotted.scatter3D(normalized['area'],  normalized["width"],normalized["length"],color='pink',edgecolor='red', s=65)
plt.title(" Houses Area  ")
plotted.set_xlabel('X-axis', fontweight ='bold')
plotted.set_ylabel('Y-axis', fontweight ='bold')
plotted.set_zlabel('Z-axis', fontweight ='bold')
plt.show()

# %% [markdown]
# # Covarience and Corelation

# %%
covar  = normalized.to_numpy()
trans =  covar.transpose()
covar  = np.dot(trans,covar)
print(covar)
# Out:
# [[ 33.12314286  51.47721113  61.3925966   61.6357053   45.78801173
#    13.9340939   46.11992608  23.22732448]
#  [ 51.47721113 105.49439385 124.1368472  125.21198532  82.49575554
#    20.73214387  55.93690225  43.9255549 ]
#  [ 61.3925966  124.1368472  172.556956   126.60144    104.1524
#    25.966       70.39        58.816     ]
#  [ 61.6357053  125.21198532 126.60144    176.053408   104.8288
#    26.29933333  71.912       55.63066667]
#  [ 45.78801173  82.49575554 104.1524     104.8288      96.04
#    25.46666667  67.          52.73333333]
#  [ 13.9340939   20.73214387  25.966       26.29933333  25.46666667
#    20.22222222  22.55555556  16.66666667]
#  [ 46.11992608  55.93690225  70.39        71.912       67.
#    22.55555556  84.77777778  35.88888889]
#  [ 23.22732448  43.9255549   58.816       55.63066667  52.73333333
#    16.66666667  35.88888889  74.        ]]

# %%
covar.shape
# Out:
# (8, 8)

# %%
price_std = normalized["price"].std()
length_std = normalized["length"].std()
width_std = normalized["width"].std()
bedrooms_std = normalized["bedrooms"].std()
bathrooms_std = normalized["bathrooms"].std()
stories_std = normalized["stories"].std()
parking_std = normalized["parking"].std()
Area_std = normalized["area"].std()
net_std = price_std*length_std*width_std*bedrooms_std*bathrooms_std*stories_std*parking_std*Area_std
corelation = covar/net_std
corelation
# Out:
# array([[ 5703768.2752697 ,  8864318.3709235 , 10571736.696293  ,
#         10613599.74312946,  7884644.57767436,  2399435.43658266,
#          7941799.85748705,  3999719.38329138],
#        [ 8864318.3709235 , 18166017.01932329, 21376226.70549545,
#         21561364.29096737, 14205677.14064439,  3570052.06242763,
#          9632272.2106655 ,  7563931.58803221],
#        [10571736.696293  , 21376226.70549545, 29714115.46326694,
#         21800626.83752872, 17934927.17486488,  4471316.25409056,
#         12121079.53190459, 10128049.63415968],
#        [10613599.74312946, 21561364.29096737, 21800626.83752872,
#         30316200.5999552 , 18051402.50083987,  4528715.88250323,
#         12383166.23523685,  9579538.78504816],
#        [ 7884644.57767436, 14205677.14064439, 17934927.17486488,
#         18051402.50083987, 16537980.93825989,  4385331.61072837,
#         11537325.31094767,  9080621.21488519],
#        [ 2399435.43658266,  3570052.06242763,  4471316.25409056,
# ...

# %% [markdown]
# # Corelation of lenght and Area

# %%
covar =  normalized[["area","length"]]
covar =  covar.to_numpy()
trans =  covar.transpose()
covar  = np.dot(trans,covar)
co_relation = covar/(length_std*Area_std)
co_relation
# Out:
# array([[1632.257594  , 1920.7021734 ],
#        [1920.7021734 , 2669.88028043]])

# %%
# Out:
# <AxesSubplot:>
